# %% [markdown]
# <a href="https://colab.research.google.com/github/zooodung/Face_Image_Emotion_Classification/blob/JS/SVM_ViT_Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import zipfile
import os

def unzip_file(zip_file_path, extract_dir):
    # 압축 파일 열기
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        # 압축 해제
        zip_ref.extractall(extract_dir)

# 압축 파일 경로와 추출할 디렉토리 경로 지정
zip_file_path = '/content/drive/MyDrive/Project/Data/img_preprocessed.zip'
extract_dir = '/content/img_p'

# 압축 파일 풀기
unzip_file(zip_file_path, extract_dir)

# %%
train_data_dir = '/content/img_p/train'
val_data_dir = '/content/img_p/val'

# %%
# !pip install vit-keras
# !pip install keras_applications
# !pip install tensorflow_addons
# !pip install optuna
# Out:
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.11.4)
# Collecting validators (from vit-keras)
#   Downloading validators-0.28.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.25.2)
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.28.1 vit-keras-0.1.2
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 9.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 26.1 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %% [markdown]
# ## Optuna 하이퍼 파라미터 최적화

# %%
import optuna
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from vit_keras import vit
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# 데이터 전처리 및 특징 추출 함수
def preprocess_data(data_dir, datagen, target_size=(224, 224), image_size=224, model_name='vit_b16'):
    generator = datagen.flow_from_directory(
        data_dir,
        target_size=target_size,
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )

    # ViT 모델 직접 생성 (이미지 크기는 고정)
    if model_name == 'vit_b16':
        vit_model = vit.vit_b16(image_size=image_size, pretrained=True, include_top=False, pretrained_top=False)
    elif model_name == 'vit_l16':
        vit_model = vit.vit_l16(image_size=image_size, pretrained=True, include_top=False, pretrained_top=False)
    else:
        raise ValueError("Invalid model name. Choose either 'vit_b16' or 'vit_l16'.")

    # 이미지 크기 조정 추가
    input_tensor = tf.keras.layers.Input((target_size[0], target_size[1], 3))
    resized_tensor = tf.keras.layers.Resizing(image_size, image_size)(input_tensor)
    output_tensor = vit_model(resized_tensor)
    model = tf.keras.Model(inputs=input_tensor, outputs=output_tensor)

    embeddings = model.predict(generator)
    labels = generator.classes
    return embeddings, labels

# 데이터 증강 설정 (필요에 따라 변경 가능)
datagen = ImageDataGenerator(rescale=1./255)

# 데이터 로드 및 특징 추출 (ViT 모델은 vit_b16, 이미지 크기 224로 고정)
train_embeddings, train_labels = preprocess_data(train_data_dir, datagen)
val_embeddings, val_labels = preprocess_data(val_data_dir, datagen)

# 레이블 인코딩
le = LabelEncoder()
train_labels = le.fit_transform(train_labels)
val_labels = le.transform(val_labels)

# Optuna objective 함수 (SVM 하이퍼파라미터만 탐색)
def objective(trial):
    # SVM 하이퍼파라미터
    svm_c = trial.suggest_float('C', 1e-4, 1e4, log=True)
    svm_gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])

    # SVM 모델 학습 및 평가
    svm = SVC(kernel='rbf', C=svm_c, gamma=svm_gamma)
    svm.fit(train_embeddings, train_labels)
    val_predictions = svm.predict(val_embeddings)
    accuracy = accuracy_score(val_labels, val_predictions)
    return accuracy

# Optuna Study 생성 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=500)  # 탐색 횟수 조절

# 최적 하이퍼파라미터 출력
print("Best SVM parameters:", study.best_params)
print("Best accuracy:", study.best_value)
# Out:
# Found 4324 images belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/vit_keras/utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 14, 14
#   warnings.warn(
# 136/136 [==============================] - 17s 108ms/step
# Found 765 images belonging to 4 classes.
# 24/24 [==============================] - 5s 109ms/step
# [I 2024-05-22 15:31:07,271] A new study created in memory with name: no-name-d7cca3c9-0277-40ff-bf46-b1e0afc2529b
# [I 2024-05-22 15:31:17,554] Trial 0 finished with value: 0.3895424836601307 and parameters: {'C': 0.00025121970213525235, 'gamma': 'auto'}. Best is trial 0 with value: 0.3895424836601307.
# [I 2024-05-22 15:31:21,620] Trial 1 finished with value: 0.8156862745098039 and parameters: {'C': 1297.2511230373525, 'gamma': 'scale'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:31:32,042] Trial 2 finished with value: 0.3908496732026144 and parameters: {'C': 0.0034087362455895182, 'gamma': 'scale'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:31:38,904] Trial 3 finished with value: 0.7294117647058823 and parameters: {'C': 0.12127555842453874, 'gamma': 'scale'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:31:42,779] Trial 4 finished with value: 0.8156862745098039 and parameters: {'C': 5801.210887286205, 'gamma': 'auto'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:31:52,995] Trial 5 finished with value: 0.3895424836601307 and parameters: {'C': 0.00040871301944321494, 'gamma': 'auto'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:32:03,273] Trial 6 finished with value: 0.3908496732026144 and parameters: {'C': 0.0012803736750230273, 'gamma': 'scale'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:32:07,284] Trial 7 finished with value: 0.8156862745098039 and parameters: {'C': 852.9899746041212, 'gamma': 'scale'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:32:11,745] Trial 8 finished with value: 0.8117647058823529 and parameters: {'C': 0.9340995499726849, 'gamma': 'scale'}. Best is trial 1 with value: 0.8156862745098039.
# [I 2024-05-22 15:32:15,677] Trial 9 finished with value: 0.8222222222222222 and parameters: {'C': 2.4212859373336606, 'gamma': 'auto'}. Best is trial 9 with value: 0.8222222222222222.
# [I 2024-05-22 15:32:19,636] Trial 10 finished with value: 0.8143790849673203 and parameters: {'C': 46.36722895563817, 'gamma': 'auto'}. Best is trial 9 with value: 0.8222222222222222.
# [I 2024-05-22 15:32:23,553] Trial 11 finished with value: 0.8143790849673203 and parameters: {'C': 44.011161983609504, 'gamma': 'auto'}. Best is trial 9 with value: 0.8222222222222222.
# [I 2024-05-22 15:32:27,621] Trial 12 finished with value: 0.8143790849673203 and parameters: {'C': 40.08541239577094, 'gamma': 'scale'}. Best is trial 9 with value: 0.8222222222222222.
# [I 2024-05-22 15:32:35,739] Trial 13 finished with value: 0.6784313725490196 and parameters: {'C': 0.050583369812539004, 'gamma': 'auto'}. Best is trial 9 with value: 0.8222222222222222.
# [I 2024-05-22 15:32:39,659] Trial 14 finished with value: 0.8248366013071895 and parameters: {'C': 6.356806486358446, 'gamma': 'scale'}. Best is trial 14 with value: 0.8248366013071895.
# [I 2024-05-22 15:32:43,535] Trial 15 finished with value: 0.8248366013071895 and parameters: {'C': 3.3510066342224065, 'gamma': 'auto'}. Best is trial 14 with value: 0.8248366013071895.
# [I 2024-05-22 15:32:47,643] Trial 16 finished with value: 0.8235294117647058 and parameters: {'C': 2.1298101078363025, 'gamma': 'scale'}. Best is trial 14 with value: 0.8248366013071895.
# [I 2024-05-22 15:32:55,306] Trial 17 finished with value: 0.6980392156862745 and parameters: {'C': 0.07345930071035381, 'gamma': 'auto'}. Best is trial 14 with value: 0.8248366013071895.
# [I 2024-05-22 15:32:59,175] Trial 18 finished with value: 0.8274509803921568 and parameters: {'C': 5.977307979933688, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:03,260] Trial 19 finished with value: 0.8156862745098039 and parameters: {'C': 257.11210863120203, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:07,246] Trial 20 finished with value: 0.8156862745098039 and parameters: {'C': 12.480914742816454, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:12,893] Trial 21 finished with value: 0.7777777777777778 and parameters: {'C': 0.32851140060125966, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:16,932] Trial 22 finished with value: 0.8222222222222222 and parameters: {'C': 9.776873684282915, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:20,738] Trial 23 finished with value: 0.8274509803921568 and parameters: {'C': 8.790447315966949, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:30,681] Trial 24 finished with value: 0.6039215686274509 and parameters: {'C': 0.016114619108131136, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:34,690] Trial 25 finished with value: 0.8156862745098039 and parameters: {'C': 188.75007632796266, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:40,223] Trial 26 finished with value: 0.7738562091503268 and parameters: {'C': 0.34637730211583845, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:44,098] Trial 27 finished with value: 0.8261437908496732 and parameters: {'C': 6.699305999983588, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:49,259] Trial 28 finished with value: 0.7908496732026143 and parameters: {'C': 0.507303346224004, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:53,076] Trial 29 finished with value: 0.8117647058823529 and parameters: {'C': 18.710146127986057, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:33:57,043] Trial 30 finished with value: 0.8156862745098039 and parameters: {'C': 118.49695716459532, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:00,865] Trial 31 finished with value: 0.8235294117647058 and parameters: {'C': 5.265354022222516, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:04,898] Trial 32 finished with value: 0.8235294117647058 and parameters: {'C': 2.055023154967451, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:08,797] Trial 33 finished with value: 0.8209150326797385 and parameters: {'C': 9.362504753651441, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:12,750] Trial 34 finished with value: 0.8156862745098039 and parameters: {'C': 454.95759084857883, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:16,773] Trial 35 finished with value: 0.8156862745098039 and parameters: {'C': 2508.304473919895, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:20,749] Trial 36 finished with value: 0.8156862745098039 and parameters: {'C': 105.98931917580795, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:25,447] Trial 37 finished with value: 0.803921568627451 and parameters: {'C': 0.7106316675566872, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:29,346] Trial 38 finished with value: 0.8156862745098039 and parameters: {'C': 21.921113395815798, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:39,588] Trial 39 finished with value: 0.5738562091503268 and parameters: {'C': 0.00903940488456408, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:45,771] Trial 40 finished with value: 0.7555555555555555 and parameters: {'C': 0.20317202043728042, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:49,604] Trial 41 finished with value: 0.8248366013071895 and parameters: {'C': 3.458790505039247, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:53,962] Trial 42 finished with value: 0.8169934640522876 and parameters: {'C': 1.3172945613478204, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:34:57,792] Trial 43 finished with value: 0.8222222222222222 and parameters: {'C': 5.336155407663005, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:01,753] Trial 44 finished with value: 0.8143790849673203 and parameters: {'C': 67.53981332516908, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:12,060] Trial 45 finished with value: 0.3895424836601307 and parameters: {'C': 0.00014436804430552873, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:15,907] Trial 46 finished with value: 0.8156862745098039 and parameters: {'C': 21.189107599024968, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:19,698] Trial 47 finished with value: 0.8196078431372549 and parameters: {'C': 5.700892634986099, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:24,185] Trial 48 finished with value: 0.8143790849673203 and parameters: {'C': 1.0439593118573227, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:28,075] Trial 49 finished with value: 0.8156862745098039 and parameters: {'C': 27.775757499565728, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:34,475] Trial 50 finished with value: 0.74640522875817 and parameters: {'C': 0.15915771372659496, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:38,300] Trial 51 finished with value: 0.8222222222222222 and parameters: {'C': 4.984804452759964, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:42,259] Trial 52 finished with value: 0.8222222222222222 and parameters: {'C': 2.73734868140822, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:46,329] Trial 53 finished with value: 0.8209150326797385 and parameters: {'C': 2.014726117716638, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:50,077] Trial 54 finished with value: 0.8261437908496732 and parameters: {'C': 7.873362587219006, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:53,910] Trial 55 finished with value: 0.8183006535947712 and parameters: {'C': 13.345574612378607, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:35:57,841] Trial 56 finished with value: 0.8143790849673203 and parameters: {'C': 49.83029755681788, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:01,734] Trial 57 finished with value: 0.8209150326797385 and parameters: {'C': 10.46092731239759, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:05,920] Trial 58 finished with value: 0.8143790849673203 and parameters: {'C': 1.4442073432165414, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:09,941] Trial 59 finished with value: 0.8156862745098039 and parameters: {'C': 77.97962604011751, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:14,810] Trial 60 finished with value: 0.7908496732026143 and parameters: {'C': 0.5512507028480778, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:18,649] Trial 61 finished with value: 0.8274509803921568 and parameters: {'C': 3.212330368053438, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:22,392] Trial 62 finished with value: 0.8248366013071895 and parameters: {'C': 6.5882110944348815, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:26,187] Trial 63 finished with value: 0.8248366013071895 and parameters: {'C': 3.428746945098382, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:30,132] Trial 64 finished with value: 0.8117647058823529 and parameters: {'C': 32.26018429986541, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:34,064] Trial 65 finished with value: 0.8156862745098039 and parameters: {'C': 14.885101438348862, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:38,796] Trial 66 finished with value: 0.803921568627451 and parameters: {'C': 0.8845340293008842, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:44,455] Trial 67 finished with value: 0.7803921568627451 and parameters: {'C': 0.3344143451117883, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:48,573] Trial 68 finished with value: 0.8156862745098039 and parameters: {'C': 243.69411092654008, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:36:57,298] Trial 69 finished with value: 0.6718954248366014 and parameters: {'C': 0.04026727220942816, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:37:01,508] Trial 70 finished with value: 0.8222222222222222 and parameters: {'C': 1.8857889475234253, 'gamma': 'scale'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:37:05,386] Trial 71 finished with value: 0.8248366013071895 and parameters: {'C': 3.4568699280170625, 'gamma': 'auto'}. Best is trial 18 with value: 0.8274509803921568.
# [I 2024-05-22 15:37:09,229] Trial 72 finished with value: 0.8287581699346406 and parameters: {'C': 8.408692241863635, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:13,111] Trial 73 finished with value: 0.8261437908496732 and parameters: {'C': 8.860795681191618, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:16,903] Trial 74 finished with value: 0.8261437908496732 and parameters: {'C': 7.23965670107546, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:20,734] Trial 75 finished with value: 0.8274509803921568 and parameters: {'C': 8.254380278754967, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:24,736] Trial 76 finished with value: 0.8156862745098039 and parameters: {'C': 38.300099834977246, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:35,284] Trial 77 finished with value: 0.3895424836601307 and parameters: {'C': 0.0005611204504343563, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:39,229] Trial 78 finished with value: 0.8156862745098039 and parameters: {'C': 14.94114037665742, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:43,150] Trial 79 finished with value: 0.8235294117647058 and parameters: {'C': 9.770535751969138, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:47,094] Trial 80 finished with value: 0.8156862745098039 and parameters: {'C': 139.14461886803034, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:50,908] Trial 81 finished with value: 0.8261437908496732 and parameters: {'C': 7.971611836558135, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:54,813] Trial 82 finished with value: 0.8169934640522876 and parameters: {'C': 22.643540350212945, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:37:58,522] Trial 83 finished with value: 0.8222222222222222 and parameters: {'C': 4.733801597754525, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:02,221] Trial 84 finished with value: 0.8261437908496732 and parameters: {'C': 7.230114556135477, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:06,188] Trial 85 finished with value: 0.8143790849673203 and parameters: {'C': 54.01272713441795, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:10,233] Trial 86 finished with value: 0.8222222222222222 and parameters: {'C': 2.7132400752159618, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:14,487] Trial 87 finished with value: 0.8143790849673203 and parameters: {'C': 1.5037486215790887, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:18,416] Trial 88 finished with value: 0.8183006535947712 and parameters: {'C': 13.60113139208085, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:22,329] Trial 89 finished with value: 0.8183006535947712 and parameters: {'C': 26.218473667299033, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:26,103] Trial 90 finished with value: 0.8222222222222222 and parameters: {'C': 5.0412369996608435, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:29,829] Trial 91 finished with value: 0.8261437908496732 and parameters: {'C': 7.884558649235849, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:33,648] Trial 92 finished with value: 0.8248366013071895 and parameters: {'C': 3.6102521740417446, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:37,380] Trial 93 finished with value: 0.8274509803921568 and parameters: {'C': 9.397821090730202, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:41,344] Trial 94 finished with value: 0.8130718954248366 and parameters: {'C': 18.14886253882261, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:45,917] Trial 95 finished with value: 0.8130718954248366 and parameters: {'C': 1.0745749353437286, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:49,800] Trial 96 finished with value: 0.8222222222222222 and parameters: {'C': 11.231645827675232, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:53,913] Trial 97 finished with value: 0.8222222222222222 and parameters: {'C': 2.1492169305440165, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:38:57,759] Trial 98 finished with value: 0.8117647058823529 and parameters: {'C': 34.420234281257954, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:02,573] Trial 99 finished with value: 0.7934640522875817 and parameters: {'C': 0.652585044380508, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:06,319] Trial 100 finished with value: 0.8235294117647058 and parameters: {'C': 4.318841203856867, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:10,058] Trial 101 finished with value: 0.8261437908496732 and parameters: {'C': 8.086410193798864, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:13,799] Trial 102 finished with value: 0.8274509803921568 and parameters: {'C': 9.180810553514583, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:17,795] Trial 103 finished with value: 0.8130718954248366 and parameters: {'C': 17.471757188836076, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:21,811] Trial 104 finished with value: 0.8222222222222222 and parameters: {'C': 2.6955240478012237, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:25,753] Trial 105 finished with value: 0.8261437908496732 and parameters: {'C': 6.036627604422089, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:29,630] Trial 106 finished with value: 0.8183006535947712 and parameters: {'C': 13.491419049540902, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:33,540] Trial 107 finished with value: 0.8156862745098039 and parameters: {'C': 92.86308890889912, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:37,746] Trial 108 finished with value: 0.8169934640522876 and parameters: {'C': 1.4989497667440357, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:41,715] Trial 109 finished with value: 0.8130718954248366 and parameters: {'C': 54.70866107276519, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:45,613] Trial 110 finished with value: 0.8183006535947712 and parameters: {'C': 25.756603268273306, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:49,410] Trial 111 finished with value: 0.8274509803921568 and parameters: {'C': 8.589805140028487, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:53,306] Trial 112 finished with value: 0.8248366013071895 and parameters: {'C': 9.874024367720958, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:39:57,155] Trial 113 finished with value: 0.8274509803921568 and parameters: {'C': 3.948078110513776, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:01,103] Trial 114 finished with value: 0.8222222222222222 and parameters: {'C': 2.70996224077506, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:04,933] Trial 115 finished with value: 0.8274509803921568 and parameters: {'C': 3.945905461463995, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:08,850] Trial 116 finished with value: 0.8209150326797385 and parameters: {'C': 3.918912859849725, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:12,970] Trial 117 finished with value: 0.8196078431372549 and parameters: {'C': 1.9734972179263723, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:16,765] Trial 118 finished with value: 0.8222222222222222 and parameters: {'C': 5.918242019264274, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:20,695] Trial 119 finished with value: 0.8117647058823529 and parameters: {'C': 18.87946623646572, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:25,398] Trial 120 finished with value: 0.8065359477124183 and parameters: {'C': 0.8742961245047073, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:29,195] Trial 121 finished with value: 0.8235294117647058 and parameters: {'C': 10.003307367873951, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:33,037] Trial 122 finished with value: 0.8248366013071895 and parameters: {'C': 4.181592298624768, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:36,857] Trial 123 finished with value: 0.8287581699346406 and parameters: {'C': 7.036183102867838, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:40,650] Trial 124 finished with value: 0.8222222222222222 and parameters: {'C': 6.316291477602535, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:44,575] Trial 125 finished with value: 0.8183006535947712 and parameters: {'C': 13.12964512676281, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:48,504] Trial 126 finished with value: 0.8222222222222222 and parameters: {'C': 2.811912767749967, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:52,330] Trial 127 finished with value: 0.8235294117647058 and parameters: {'C': 4.412683790194678, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:40:56,128] Trial 128 finished with value: 0.8156862745098039 and parameters: {'C': 21.904327892602897, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:00,267] Trial 129 finished with value: 0.8156862745098039 and parameters: {'C': 9916.963866651915, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:04,774] Trial 130 finished with value: 0.8156862745098039 and parameters: {'C': 1.1909634259864839, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:08,587] Trial 131 finished with value: 0.8287581699346406 and parameters: {'C': 7.616705545861477, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:12,455] Trial 132 finished with value: 0.8274509803921568 and parameters: {'C': 7.26272935829127, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:16,353] Trial 133 finished with value: 0.8196078431372549 and parameters: {'C': 12.316371286687527, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:20,189] Trial 134 finished with value: 0.8196078431372549 and parameters: {'C': 5.669486989919797, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:24,147] Trial 135 finished with value: 0.8248366013071895 and parameters: {'C': 3.336155675198082, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:28,471] Trial 136 finished with value: 0.8143790849673203 and parameters: {'C': 1.5632065087685032, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:32,341] Trial 137 finished with value: 0.8261437908496732 and parameters: {'C': 8.025892876392607, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:36,288] Trial 138 finished with value: 0.8143790849673203 and parameters: {'C': 15.155165008584799, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:40,410] Trial 139 finished with value: 0.8235294117647058 and parameters: {'C': 2.260258983025277, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:44,496] Trial 140 finished with value: 0.8130718954248366 and parameters: {'C': 32.83250561617628, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:48,360] Trial 141 finished with value: 0.8274509803921568 and parameters: {'C': 6.933197767879331, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:52,308] Trial 142 finished with value: 0.8222222222222222 and parameters: {'C': 4.713397097195488, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:41:56,213] Trial 143 finished with value: 0.8235294117647058 and parameters: {'C': 9.830308940763741, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:00,078] Trial 144 finished with value: 0.8235294117647058 and parameters: {'C': 6.1813279340989515, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:04,002] Trial 145 finished with value: 0.8248366013071895 and parameters: {'C': 3.5300952766055986, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:07,902] Trial 146 finished with value: 0.8117647058823529 and parameters: {'C': 16.349906971932135, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:11,748] Trial 147 finished with value: 0.8209150326797385 and parameters: {'C': 11.043956741480685, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:15,510] Trial 148 finished with value: 0.8274509803921568 and parameters: {'C': 6.818431647261603, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:19,293] Trial 149 finished with value: 0.8274509803921568 and parameters: {'C': 7.797913833745067, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:23,129] Trial 150 finished with value: 0.8156862745098039 and parameters: {'C': 22.283982602202805, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:26,881] Trial 151 finished with value: 0.8261437908496732 and parameters: {'C': 8.125030617844397, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:30,628] Trial 152 finished with value: 0.8209150326797385 and parameters: {'C': 5.8628891320196574, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:34,407] Trial 153 finished with value: 0.8261437908496732 and parameters: {'C': 3.994525868339889, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:38,316] Trial 154 finished with value: 0.8222222222222222 and parameters: {'C': 2.547598711216345, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:42,086] Trial 155 finished with value: 0.8222222222222222 and parameters: {'C': 11.458682054810948, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:45,862] Trial 156 finished with value: 0.8222222222222222 and parameters: {'C': 5.004717178640695, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:49,585] Trial 157 finished with value: 0.8287581699346406 and parameters: {'C': 7.56421358774626, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:42:53,494] Trial 158 finished with value: 0.8130718954248366 and parameters: {'C': 18.3184045599283, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:03,796] Trial 159 finished with value: 0.3895424836601307 and parameters: {'C': 0.001802246869168764, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:07,925] Trial 160 finished with value: 0.8196078431372549 and parameters: {'C': 1.9057670576086472, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:11,786] Trial 161 finished with value: 0.8261437908496732 and parameters: {'C': 7.985580360828058, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:15,713] Trial 162 finished with value: 0.8248366013071895 and parameters: {'C': 3.3971140521222596, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:19,570] Trial 163 finished with value: 0.8287581699346406 and parameters: {'C': 7.579750218978946, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:23,470] Trial 164 finished with value: 0.8196078431372549 and parameters: {'C': 12.506101560152755, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:27,336] Trial 165 finished with value: 0.8196078431372549 and parameters: {'C': 5.655044805806281, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:31,313] Trial 166 finished with value: 0.8156862745098039 and parameters: {'C': 40.94633423742892, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:35,145] Trial 167 finished with value: 0.8261437908496732 and parameters: {'C': 8.983335963804969, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:39,162] Trial 168 finished with value: 0.8183006535947712 and parameters: {'C': 25.009246276624058, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:43,043] Trial 169 finished with value: 0.8274509803921568 and parameters: {'C': 3.8099170081034033, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:46,877] Trial 170 finished with value: 0.8222222222222222 and parameters: {'C': 6.008427879810845, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:50,714] Trial 171 finished with value: 0.8274509803921568 and parameters: {'C': 8.155763657262465, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:54,642] Trial 172 finished with value: 0.8183006535947712 and parameters: {'C': 13.035969258199893, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:43:58,418] Trial 173 finished with value: 0.8143790849673203 and parameters: {'C': 15.202055579147121, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:02,144] Trial 174 finished with value: 0.8274509803921568 and parameters: {'C': 6.841501493327471, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:05,991] Trial 175 finished with value: 0.8235294117647058 and parameters: {'C': 2.910648530896391, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:09,753] Trial 176 finished with value: 0.8235294117647058 and parameters: {'C': 4.254431615815609, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:13,485] Trial 177 finished with value: 0.8235294117647058 and parameters: {'C': 9.813131755118265, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:17,264] Trial 178 finished with value: 0.8222222222222222 and parameters: {'C': 5.078355334160665, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:21,069] Trial 179 finished with value: 0.8130718954248366 and parameters: {'C': 17.787624093237365, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:24,729] Trial 180 finished with value: 0.8261437908496732 and parameters: {'C': 7.219029897471556, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:28,579] Trial 181 finished with value: 0.8248366013071895 and parameters: {'C': 3.5863538417063845, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:32,505] Trial 182 finished with value: 0.8222222222222222 and parameters: {'C': 2.498678257367048, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:36,243] Trial 183 finished with value: 0.8235294117647058 and parameters: {'C': 10.495458316987019, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:40,003] Trial 184 finished with value: 0.8209150326797385 and parameters: {'C': 4.5590602447156865, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:43,680] Trial 185 finished with value: 0.8261437908496732 and parameters: {'C': 7.170550959657172, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:47,745] Trial 186 finished with value: 0.8196078431372549 and parameters: {'C': 1.8282293616803749, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:51,548] Trial 187 finished with value: 0.8261437908496732 and parameters: {'C': 3.3108508689355984, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:55,337] Trial 188 finished with value: 0.8235294117647058 and parameters: {'C': 10.469357632473672, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:44:59,046] Trial 189 finished with value: 0.8222222222222222 and parameters: {'C': 4.999240774790756, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:02,827] Trial 190 finished with value: 0.8143790849673203 and parameters: {'C': 14.545443826259856, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:06,505] Trial 191 finished with value: 0.8287581699346406 and parameters: {'C': 7.005533513926717, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:10,225] Trial 192 finished with value: 0.8235294117647058 and parameters: {'C': 6.5346741091987965, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:13,906] Trial 193 finished with value: 0.8274509803921568 and parameters: {'C': 8.567711766811003, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:17,677] Trial 194 finished with value: 0.8235294117647058 and parameters: {'C': 4.349898111349042, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:21,417] Trial 195 finished with value: 0.8209150326797385 and parameters: {'C': 11.035945108718108, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:25,283] Trial 196 finished with value: 0.8274509803921568 and parameters: {'C': 3.032845235573206, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:28,988] Trial 197 finished with value: 0.8222222222222222 and parameters: {'C': 6.212211846960371, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:32,922] Trial 198 finished with value: 0.8130718954248366 and parameters: {'C': 19.952853566980192, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:36,796] Trial 199 finished with value: 0.8274509803921568 and parameters: {'C': 8.500033036477951, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:40,624] Trial 200 finished with value: 0.8222222222222222 and parameters: {'C': 5.078202756547, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:44,472] Trial 201 finished with value: 0.8274509803921568 and parameters: {'C': 7.708025619997029, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:48,421] Trial 202 finished with value: 0.8169934640522876 and parameters: {'C': 13.65271098699749, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:52,275] Trial 203 finished with value: 0.8287581699346406 and parameters: {'C': 8.65449320150308, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:45:56,186] Trial 204 finished with value: 0.8274509803921568 and parameters: {'C': 3.9053256905033775, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:00,080] Trial 205 finished with value: 0.8222222222222222 and parameters: {'C': 11.263707643211394, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:04,188] Trial 206 finished with value: 0.8235294117647058 and parameters: {'C': 2.3802566941503414, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:08,004] Trial 207 finished with value: 0.8261437908496732 and parameters: {'C': 6.679921478473149, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:11,885] Trial 208 finished with value: 0.8209150326797385 and parameters: {'C': 4.578418168480474, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:15,867] Trial 209 finished with value: 0.8156862745098039 and parameters: {'C': 940.2350234409056, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:19,836] Trial 210 finished with value: 0.8183006535947712 and parameters: {'C': 26.669010442601955, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:23,681] Trial 211 finished with value: 0.8274509803921568 and parameters: {'C': 8.579760240891249, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:27,504] Trial 212 finished with value: 0.8117647058823529 and parameters: {'C': 16.051526303871935, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:31,272] Trial 213 finished with value: 0.8274509803921568 and parameters: {'C': 6.889540217815347, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:34,977] Trial 214 finished with value: 0.8235294117647058 and parameters: {'C': 10.438839294300086, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:38,703] Trial 215 finished with value: 0.8209150326797385 and parameters: {'C': 5.82536446326679, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:42,584] Trial 216 finished with value: 0.8248366013071895 and parameters: {'C': 8.604454534146873, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:46,308] Trial 217 finished with value: 0.8274509803921568 and parameters: {'C': 3.852354323376695, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:50,071] Trial 218 finished with value: 0.8183006535947712 and parameters: {'C': 12.234939886868075, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:53,807] Trial 219 finished with value: 0.8222222222222222 and parameters: {'C': 5.008506868736119, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:46:57,672] Trial 220 finished with value: 0.8248366013071895 and parameters: {'C': 2.9516965377211863, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:01,391] Trial 221 finished with value: 0.8287581699346406 and parameters: {'C': 7.049971622136227, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:05,071] Trial 222 finished with value: 0.8287581699346406 and parameters: {'C': 7.458915805030267, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:08,806] Trial 223 finished with value: 0.8209150326797385 and parameters: {'C': 5.855716609679413, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:12,729] Trial 224 finished with value: 0.8143790849673203 and parameters: {'C': 15.594649413111789, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:16,497] Trial 225 finished with value: 0.8274509803921568 and parameters: {'C': 8.039406797858458, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:20,359] Trial 226 finished with value: 0.8235294117647058 and parameters: {'C': 10.248238665871803, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:24,271] Trial 227 finished with value: 0.8261437908496732 and parameters: {'C': 3.997610855839928, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:28,084] Trial 228 finished with value: 0.8209150326797385 and parameters: {'C': 5.541234470102396, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:31,934] Trial 229 finished with value: 0.8196078431372549 and parameters: {'C': 12.867945027418568, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:35,732] Trial 230 finished with value: 0.8287581699346406 and parameters: {'C': 6.97924693329599, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:39,531] Trial 231 finished with value: 0.8274509803921568 and parameters: {'C': 6.825021131876402, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:43,356] Trial 232 finished with value: 0.8274509803921568 and parameters: {'C': 9.211021453802287, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:47,165] Trial 233 finished with value: 0.8235294117647058 and parameters: {'C': 4.866650428657074, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:51,104] Trial 234 finished with value: 0.8261437908496732 and parameters: {'C': 3.0565266962871167, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:54,927] Trial 235 finished with value: 0.8261437908496732 and parameters: {'C': 7.234140491784086, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:47:58,903] Trial 236 finished with value: 0.8143790849673203 and parameters: {'C': 17.2863550211737, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:02,687] Trial 237 finished with value: 0.8274509803921568 and parameters: {'C': 9.092550982024699, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:06,474] Trial 238 finished with value: 0.8248366013071895 and parameters: {'C': 3.9998326634324566, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:10,220] Trial 239 finished with value: 0.8196078431372549 and parameters: {'C': 5.6936431355024775, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:13,974] Trial 240 finished with value: 0.8222222222222222 and parameters: {'C': 11.740280706914584, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:17,685] Trial 241 finished with value: 0.8261437908496732 and parameters: {'C': 7.208776301645826, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:21,441] Trial 242 finished with value: 0.8261437908496732 and parameters: {'C': 8.857226725060853, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:25,132] Trial 243 finished with value: 0.8209150326797385 and parameters: {'C': 5.524974666994692, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:28,895] Trial 244 finished with value: 0.8222222222222222 and parameters: {'C': 11.26096777255502, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:32,636] Trial 245 finished with value: 0.8287581699346406 and parameters: {'C': 7.5045700897179985, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:36,415] Trial 246 finished with value: 0.8248366013071895 and parameters: {'C': 3.640790263558958, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:40,375] Trial 247 finished with value: 0.8130718954248366 and parameters: {'C': 17.39501580759956, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:44,491] Trial 248 finished with value: 0.8209150326797385 and parameters: {'C': 2.093058401610132, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:48,341] Trial 249 finished with value: 0.8248366013071895 and parameters: {'C': 6.587660959216553, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:52,297] Trial 250 finished with value: 0.8183006535947712 and parameters: {'C': 13.390782251793514, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:48:56,166] Trial 251 finished with value: 0.8209150326797385 and parameters: {'C': 4.58879885536806, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:49:00,000] Trial 252 finished with value: 0.8274509803921568 and parameters: {'C': 8.53038953866863, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:49:03,992] Trial 253 finished with value: 0.8261437908496732 and parameters: {'C': 2.9474376549037222, 'gamma': 'scale'}. Best is trial 72 with value: 0.8287581699346406.
# [I 2024-05-22 15:49:07,865] Trial 254 finished with value: 0.8222222222222222 and parameters: {'C': 6.193794587829526, 'gamma': 'auto'}. Best is trial 72 with value: 0.8287581699346406.
# ...
# [I 2024-05-22 16:00:34,104] Trial 416 finished with value: 0.8117647058823529 and parameters: {'C': 0.9235700571873438, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:00:38,108] Trial 417 finished with value: 0.8274509803921568 and parameters: {'C': 2.891878996442732, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:00:42,145] Trial 418 finished with value: 0.8287581699346406 and parameters: {'C': 2.4586107414040734, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:00:47,309] Trial 419 finished with value: 0.792156862745098 and parameters: {'C': 0.5217038498254681, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:00:51,630] Trial 420 finished with value: 0.8169934640522876 and parameters: {'C': 1.381203166223897, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:00:55,600] Trial 421 finished with value: 0.8261437908496732 and parameters: {'C': 2.9707952843184633, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:00,128] Trial 422 finished with value: 0.8130718954248366 and parameters: {'C': 1.0904242882296202, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:04,271] Trial 423 finished with value: 0.8235294117647058 and parameters: {'C': 2.0462686857787684, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:08,265] Trial 424 finished with value: 0.8261437908496732 and parameters: {'C': 2.9998585717055835, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:12,563] Trial 425 finished with value: 0.8196078431372549 and parameters: {'C': 1.666884561511081, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:16,527] Trial 426 finished with value: 0.8274509803921568 and parameters: {'C': 3.515394406848107, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:20,611] Trial 427 finished with value: 0.8300653594771242 and parameters: {'C': 2.605556001250654, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:24,773] Trial 428 finished with value: 0.8235294117647058 and parameters: {'C': 2.1495118175344112, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:29,027] Trial 429 finished with value: 0.8169934640522876 and parameters: {'C': 1.540491737398928, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:33,562] Trial 430 finished with value: 0.8130718954248366 and parameters: {'C': 1.1028080218770282, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:37,594] Trial 431 finished with value: 0.8300653594771242 and parameters: {'C': 2.5806616908013895, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:41,650] Trial 432 finished with value: 0.8248366013071895 and parameters: {'C': 2.420964951398279, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:46,392] Trial 433 finished with value: 0.8052287581699347 and parameters: {'C': 0.7745588799049059, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:50,626] Trial 434 finished with value: 0.8222222222222222 and parameters: {'C': 1.8238571308515614, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:54,600] Trial 435 finished with value: 0.8274509803921568 and parameters: {'C': 2.9154317156404526, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:01:59,021] Trial 436 finished with value: 0.8143790849673203 and parameters: {'C': 1.3109143440545905, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:03,073] Trial 437 finished with value: 0.8313725490196079 and parameters: {'C': 2.7615987369481956, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:07,182] Trial 438 finished with value: 0.8248366013071895 and parameters: {'C': 2.2539529844918027, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:11,164] Trial 439 finished with value: 0.8287581699346406 and parameters: {'C': 3.3672494997563733, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:15,397] Trial 440 finished with value: 0.8196078431372549 and parameters: {'C': 1.683508764922057, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:19,404] Trial 441 finished with value: 0.8300653594771242 and parameters: {'C': 2.6588549906291905, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:23,402] Trial 442 finished with value: 0.8300653594771242 and parameters: {'C': 2.665042731531885, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:27,780] Trial 443 finished with value: 0.8143790849673203 and parameters: {'C': 1.2960246185485251, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:31,853] Trial 444 finished with value: 0.8248366013071895 and parameters: {'C': 2.2732836288963645, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:35,923] Trial 445 finished with value: 0.8300653594771242 and parameters: {'C': 2.6538843126159963, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:40,546] Trial 446 finished with value: 0.8117647058823529 and parameters: {'C': 0.9370394077341323, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:44,737] Trial 447 finished with value: 0.8183006535947712 and parameters: {'C': 1.7644474908277703, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:48,739] Trial 448 finished with value: 0.8300653594771242 and parameters: {'C': 2.530624930702835, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:52,797] Trial 449 finished with value: 0.8287581699346406 and parameters: {'C': 2.5925247958768023, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:02:57,183] Trial 450 finished with value: 0.8156862745098039 and parameters: {'C': 1.2799560804753294, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:01,406] Trial 451 finished with value: 0.8222222222222222 and parameters: {'C': 1.8175810259782603, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:05,425] Trial 452 finished with value: 0.8287581699346406 and parameters: {'C': 2.596618119410041, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:10,226] Trial 453 finished with value: 0.8 and parameters: {'C': 0.6744472747754408, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:14,181] Trial 454 finished with value: 0.8287581699346406 and parameters: {'C': 3.3892054557113624, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:18,389] Trial 455 finished with value: 0.8222222222222222 and parameters: {'C': 1.833379769835441, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:22,952] Trial 456 finished with value: 0.8143790849673203 and parameters: {'C': 1.0521647727843124, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:26,975] Trial 457 finished with value: 0.8313725490196079 and parameters: {'C': 2.7700922080207677, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:30,999] Trial 458 finished with value: 0.8300653594771242 and parameters: {'C': 2.657923498101564, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:35,108] Trial 459 finished with value: 0.8261437908496732 and parameters: {'C': 2.3510851944147917, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:39,355] Trial 460 finished with value: 0.8196078431372549 and parameters: {'C': 1.6496552269072913, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:43,328] Trial 461 finished with value: 0.8287581699346406 and parameters: {'C': 2.8338811828903134, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:47,645] Trial 462 finished with value: 0.8169934640522876 and parameters: {'C': 1.378189445261821, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:51,754] Trial 463 finished with value: 0.8248366013071895 and parameters: {'C': 2.2698759914255278, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:03:55,713] Trial 464 finished with value: 0.8274509803921568 and parameters: {'C': 3.2700561260927996, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:00,158] Trial 465 finished with value: 0.8156862745098039 and parameters: {'C': 1.1707361784705483, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:04,279] Trial 466 finished with value: 0.8235294117647058 and parameters: {'C': 2.15399021051456, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:08,237] Trial 467 finished with value: 0.8274509803921568 and parameters: {'C': 3.295292791869833, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:12,532] Trial 468 finished with value: 0.8169934640522876 and parameters: {'C': 1.5743212783946325, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:17,188] Trial 469 finished with value: 0.8065359477124183 and parameters: {'C': 0.8627810414999741, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:21,124] Trial 470 finished with value: 0.8248366013071895 and parameters: {'C': 3.5740153607626586, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:25,117] Trial 471 finished with value: 0.8287581699346406 and parameters: {'C': 2.467266813945824, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:29,319] Trial 472 finished with value: 0.8222222222222222 and parameters: {'C': 1.8475130084826836, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:33,300] Trial 473 finished with value: 0.8261437908496732 and parameters: {'C': 3.552473274500676, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:40,864] Trial 474 finished with value: 0.7071895424836602 and parameters: {'C': 0.07918089504946677, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:45,193] Trial 475 finished with value: 0.8143790849673203 and parameters: {'C': 1.3324414758217842, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:49,226] Trial 476 finished with value: 0.8287581699346406 and parameters: {'C': 2.5925150714741134, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:53,414] Trial 477 finished with value: 0.8222222222222222 and parameters: {'C': 1.8448359969242865, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:04:57,334] Trial 478 finished with value: 0.8248366013071895 and parameters: {'C': 3.6897313148812483, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:02,655] Trial 479 finished with value: 0.788235294117647 and parameters: {'C': 0.4586776364569446, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:06,662] Trial 480 finished with value: 0.8300653594771242 and parameters: {'C': 2.611542281841995, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:10,716] Trial 481 finished with value: 0.8300653594771242 and parameters: {'C': 2.53003973023739, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:14,975] Trial 482 finished with value: 0.8183006535947712 and parameters: {'C': 1.7716491408955783, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:19,515] Trial 483 finished with value: 0.8130718954248366 and parameters: {'C': 1.013278851561528, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:23,609] Trial 484 finished with value: 0.8287581699346406 and parameters: {'C': 2.5986824100541175, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:27,545] Trial 485 finished with value: 0.8222222222222222 and parameters: {'C': 3.813618980113742, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:31,784] Trial 486 finished with value: 0.8209150326797385 and parameters: {'C': 1.8038381105091, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:35,804] Trial 487 finished with value: 0.8274509803921568 and parameters: {'C': 2.8492026216031574, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:40,186] Trial 488 finished with value: 0.8143790849673203 and parameters: {'C': 1.2989327259268648, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:44,126] Trial 489 finished with value: 0.8222222222222222 and parameters: {'C': 3.832371413915758, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:48,202] Trial 490 finished with value: 0.8248366013071895 and parameters: {'C': 2.2488741894207975, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:52,128] Trial 491 finished with value: 0.8209150326797385 and parameters: {'C': 3.9075431234801683, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:05:56,406] Trial 492 finished with value: 0.8169934640522876 and parameters: {'C': 1.445114674787458, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:00,374] Trial 493 finished with value: 0.8313725490196079 and parameters: {'C': 2.703046294951977, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:04,512] Trial 494 finished with value: 0.8209150326797385 and parameters: {'C': 1.813056446546816, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:08,422] Trial 495 finished with value: 0.8209150326797385 and parameters: {'C': 4.030799543629772, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:13,018] Trial 496 finished with value: 0.8065359477124183 and parameters: {'C': 0.8383167289208262, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:17,028] Trial 497 finished with value: 0.8313725490196079 and parameters: {'C': 2.7695057850878784, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:21,168] Trial 498 finished with value: 0.8222222222222222 and parameters: {'C': 1.9795456724216172, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# [I 2024-05-22 16:06:25,059] Trial 499 finished with value: 0.8209150326797385 and parameters: {'C': 4.1351378845108036, 'gamma': 'scale'}. Best is trial 355 with value: 0.8313725490196079.
# Best SVM parameters: {'C': 2.808856612710054, 'gamma': 'scale'}
# Best accuracy: 0.8313725490196079

# %% [markdown]
# ## SVM, ViT

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import LabelEncoder
from vit_keras import vit
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# 데이터 전처리 및 특징 추출 함수
def preprocess_data(data_dir, datagen, target_size, image_size):
    generator = datagen.flow_from_directory(
        data_dir,
        target_size=target_size,
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )

    vit_model = vit.vit_b16(image_size=image_size, pretrained=True, include_top=False, pretrained_top=False)
    input_tensor = tf.keras.layers.Input((target_size[0], target_size[1], 3))
    resized_tensor = tf.keras.layers.Resizing(image_size, image_size)(input_tensor)
    output_tensor = vit_model(resized_tensor)
    model = tf.keras.Model(inputs=input_tensor, outputs=output_tensor)

    embeddings = model.predict(generator)
    labels = generator.classes

    return embeddings, labels

datagen = ImageDataGenerator(rescale=1./255)

# 최적 하이퍼파라미터 적용
best_vit_image_size = 224
best_svm_c = 2.808856612710054
best_svm_gamma = 'scale'

train_embeddings, train_labels = preprocess_data(train_data_dir, datagen, target_size=(best_vit_image_size, best_vit_image_size), image_size=best_vit_image_size)
val_embeddings, val_labels = preprocess_data(val_data_dir, datagen, target_size=(best_vit_image_size, best_vit_image_size), image_size=best_vit_image_size)

le = LabelEncoder() # 인코딩
train_labels = le.fit_transform(train_labels)
val_labels = le.transform(val_labels)

# SVM 모델 학습
svm = SVC(kernel='rbf', C=best_svm_c, gamma=best_svm_gamma)
svm.fit(train_embeddings, train_labels)

# 모델 평가
val_predictions = svm.predict(val_embeddings)
accuracy = np.mean(val_predictions == val_labels)
print(f"Validation Accuracy (with best params): {accuracy:.4f}")
# Out:
# Found 4324 images belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/vit_keras/utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 14, 14
#   warnings.warn(
# 136/136 [==============================] - 17s 108ms/step
# Found 765 images belonging to 4 classes.
# 24/24 [==============================] - 5s 108ms/step
# Validation Accuracy (with best params): 0.8314

# %% [markdown]
# ### 성능평가

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# 정확도 (Accuracy)
accuracy = accuracy_score(val_labels, val_predictions)
print(f"Accuracy: {accuracy:.4f}")

# 정밀도 (Precision), 재현율 (Recall), F1 점수 (F1-score)
precision = precision_score(val_labels, val_predictions, average='weighted')
recall = recall_score(val_labels, val_predictions, average='weighted')
f1 = f1_score(val_labels, val_predictions, average='weighted')
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")

# 분류 보고서 (Classification Report)
print("\nClassification Report:")
target_names = [str(label) for label in le.classes_]  # Convert labels to strings
print(classification_report(val_labels, val_predictions, target_names=target_names))


# 혼동 행렬 (Confusion Matrix)
print("\nConfusion Matrix:")
conf_matrix = confusion_matrix(val_labels, val_predictions)
print(conf_matrix)
# Out:
# Accuracy: 0.8314
# Precision: 0.8299
# Recall: 0.8314
# F1-score: 0.8304
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       194
#            1       0.89      0.93      0.91       192
#            2       0.82      0.83      0.83       193
#            3       0.84      0.84      0.84       186
#
#     accuracy                           0.83       765
#    macro avg       0.83      0.83      0.83       765
# weighted avg       0.83      0.83      0.83       765
#
#
# Confusion Matrix:
# [[140   9  24  21]
#  [  8 178   3   3]
#  [ 25   1 161   6]
#  [ 10  11   8 157]]

# %% [markdown]
# ## model export

# %%
import joblib

# Save the model
joblib.dump(svm, '/content/drive/MyDrive/Project/svm_vitembedding.joblib')
# Out:
# ['/content/drive/MyDrive/Project/svm_vitembedding.joblib']

# %%
loaded_svm = joblib.load('/content/drive/MyDrive/Project/svm_vitembedding.joblib')
